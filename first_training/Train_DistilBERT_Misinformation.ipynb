# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
# !pip install transformers datasets evaluate scikit-learn tqdm
# Out:
# Requirement already satisfied: transformers in c:\users\mirac\anaconda3\lib\site-packages (4.32.1)
# Requirement already satisfied: datasets in c:\users\mirac\anaconda3\lib\site-packages (2.12.0)
# Collecting evaluate
#   Obtaining dependency information for evaluate from https://files.pythonhosted.org/packages/a2/e7/cbca9e2d2590eb9b5aa8f7ebabe1beb1498f9462d2ecede5c9fd9735faaf/evaluate-0.4.3-py3-none-any.whl.metadata
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: scikit-learn in c:\users\mirac\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: tqdm in c:\users\mirac\anaconda3\lib\site-packages (4.65.0)
# Requirement already satisfied: filelock in c:\users\mirac\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\mirac\anaconda3\lib\site-packages (from transformers) (0.15.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\mirac\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\mirac\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mirac\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mirac\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\mirac\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\mirac\anaconda3\lib\site-packages (from transformers) (0.13.2)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\mirac\anaconda3\lib\site-packages (from transformers) (0.3.2)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\mirac\anaconda3\lib\site-packages (from datasets) (11.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in c:\users\mirac\anaconda3\lib\site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in c:\users\mirac\anaconda3\lib\site-packages (from datasets) (2.0.3)
# Requirement already satisfied: xxhash in c:\users\mirac\anaconda3\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in c:\users\mirac\anaconda3\lib\site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in c:\users\mirac\anaconda3\lib\site-packages (from datasets) (2023.4.0)
# Requirement already satisfied: aiohttp in c:\users\mirac\anaconda3\lib\site-packages (from datasets) (3.8.5)
# Requirement already satisfied: responses<0.19 in c:\users\mirac\anaconda3\lib\site-packages (from datasets) (0.13.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\mirac\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\mirac\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mirac\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: colorama in c:\users\mirac\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mirac\anaconda3\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\mirac\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mirac\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mirac\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mirac\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mirac\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mirac\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mirac\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.11.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mirac\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mirac\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mirac\anaconda3\lib\site-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: six in c:\users\mirac\anaconda3\lib\site-packages (from responses<0.19->datasets) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mirac\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mirac\anaconda3\lib\site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mirac\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.0 kB ? eta -:--:--
#    --------- ------------------------------ 20.5/84.0 kB 640.0 kB/s eta 0:00:01
#    ---------------------------------------- 84.0/84.0 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from transformers import DataCollatorWithPadding
from sklearn.metrics import classification_report
import numpy as np
import evaluate

# %%
df = pd.read_csv("data/combined_dataset_forbehandlad.csv")
df = df[["text", "label"]].dropna().reset_index(drop=True)

# %%
dataset = Dataset.from_pandas(df)
dataset = dataset.train_test_split(test_size=0.2, seed=42)

# %%
checkpoint = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=2)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def tokenize(batch):
    return tokenizer(batch["text"], truncation=True)

# %%
dataset = dataset.map(tokenize, batched=True)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
# Map:   0%|          | 0/844 [00:00<?, ? examples/s]
# Map:   0%|          | 0/212 [00:00<?, ? examples/s]

# %%
metric = evaluate.load("accuracy")

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    acc = metric.compute(predictions=predictions, references=labels)
    return acc

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
training_args = TrainingArguments(
    output_dir="./bert_results",
    # The parameter has been replaced with evaluation_strategy="epoch"
    eval_steps = 100, # Evaluate every 100 steps.
    save_strategy="no",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    logging_dir="./logs",

)
# Out:
# Using the `WANDB_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# C:\Users\mirac\AppData\Local\Temp\ipykernel_20240\3647305547.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
# c:\Users\mirac\anaconda3\Lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='318' max='318' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [318/318 02:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# TrainOutput(global_step=318, training_loss=0.29912605525562597, metrics={'train_runtime': 162.9751, 'train_samples_per_second': 15.536, 'train_steps_per_second': 1.951, 'total_flos': 13784888672640.0, 'train_loss': 0.29912605525562597, 'epoch': 3.0})

# %%
from transformers import DistilBertForSequenceClassification, DistilBertTokenizer

# Spara modellen
model.save_pretrained('model/bert_model')

# Spara tokenizern
tokenizer.save_pretrained('model/bert_model')
# Out:
# ('model/bert_model\\tokenizer_config.json',
#  'model/bert_model\\special_tokens_map.json',
#  'model/bert_model\\vocab.txt',
#  'model/bert_model\\added_tokens.json',
#  'model/bert_model\\tokenizer.json')

# %%
predictions = trainer.predict(dataset["test"])
y_true = predictions.label_ids
y_pred = np.argmax(predictions.predictions, axis=-1)

# %%
print("=== Klassificeringsrapport ===")
print(classification_report(y_true, y_pred, digits=3))
# Out:
# === Klassificeringsrapport ===
#               precision    recall  f1-score   support
#
#            0      0.881     0.851     0.865        87
#            1      0.898     0.920     0.909       125
#
#     accuracy                          0.892       212
#    macro avg      0.890     0.885     0.887       212
# weighted avg      0.891     0.892     0.891       212

# %%
print(df['source'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mirac\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\mirac\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\mirac\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'source'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(df['source'].value_counts())
#
# File c:\Users\mirac\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\mirac\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'source'
